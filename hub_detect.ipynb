# %%
import torch

"""
param1 本文件夹下面的测试图片
param2 解析模型为yolov5s
param3 如果为本地的数据源则填写local数据
"""
# Model
model = torch.hub.load("./", "yolov5s", source="local")

# Images
img = "./data/images/zidane.jpg"

# Inference
results = model(img)

# Result
results.show()
# Out:
# YOLOv5  v7.0-350-g6096750f Python-3.8.19 torch-2.2.1 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=1280x720>
